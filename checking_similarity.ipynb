# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import os
import sys
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import cm as cm

# %run '/Users/angela/Open_Malaria_2/Open_Malaria_2/malaria_functions.ipynb'

# %%
os.chdir("/Users/angela/Open_Malaria_2/Open_Malaria_2")

# %%
sim_df = pd.read_table('/Users/angela/Distance_matrix/smiles_malaria_res.txt', sep=' ', header=None)
c_t_c = [0, 3]
c_t_c2 = [2, 457]

# %%
sim_df[c_t_c] = sim_df[c_t_c].replace({'\[':''}, regex=True)
sim_df[2] = sim_df[2].replace({'\'\]':''}, regex=True)
sim_df[2] = sim_df[2].replace({'\'':''}, regex=True)
sim_df[457] = sim_df[457].replace({'\]':''}, regex=True)

# %%
pd.set_option('max_rows', 160)
sim_df
# Out:
#                0                               1    \
# 0    ['OSM-S-175',  'UEOZBGRWGZEYED-UHFFFAOYSA-N',
# 1    ['OSM-S-177',  'ZTZAUSYERGBZNZ-UHFFFAOYSA-N',
# 2    ['OSM-S-201',  'IVENWLQUYSRINV-UHFFFAOYSA-N',
# 3    ['OSM-S-202',  'AJGOFYWOTIIYLR-UHFFFAOYSA-N',
# 4    ['OSM-S-204',  'WBRLFZGDBUVKSB-UHFFFAOYSA-N',
# 5    ['OSM-S-218',  'PERKBMZWWUEZNJ-UHFFFAOYSA-N',
# 6    ['OSM-S-254',  'QKXZFYOMVFGRGS-UHFFFAOYSA-N',
# 7    ['OSM-S-272',  'PMHUSEXABGDNGS-UHFFFAOYSA-N',
# 8    ['OSM-S-278',  'YUTTVQUFLHMVCQ-UHFFFAOYSA-N',
# 9    ['OSM-S-279',  'GEHCMLKWLSBHDX-UHFFFAOYSA-N',
# 10   ['OSM-S-293',  'VURCFSOLNXCMTN-UHFFFAOYSA-N',
# 11   ['OSM-S-353',  'MGANJQKOPZQELF-UHFFFAOYSA-N',
# 12   ['OSM-S-363',  'GFJJCWGNCVLFNL-UHFFFAOYSA-N',
# 13   ['OSM-S-364',  'XRLPEWWQEWQISU-UHFFFAOYSA-N',
# 14   ['OSM-S-366',  'GIBSJTKADOSTIA-UHFFFAOYSA-N',
# 15   ['OSM-S-367',  'CAFUHAVOTBMKAN-UHFFFAOYSA-N',
# 16   ['OSM-S-368',  'BHCAOWNYTVGIBQ-UHFFFAOYSA-N',
# ...

# %%
#pd.set_option('max_colwidth', 100)
#sim_df[2]
smiles_list = sim_df[2]
smiles_list
# Out:
# 0                    O=C(Nc1ccnc(C(F)(F)F)c1)C1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21
# 1                          O=C(C1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21)N1Cc2ccccc2C1
# 2                         Cc1c(Cl)cccc1NC(=O)C1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21
# 3                          O=C(Nc1cccc(Cl)c1)C1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21
# 4                         O=C(Nc1cccc(Cl)c1F)C1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21
# 5                          COC(COC1=CN=Cc2nnc(-c3ccc(C#N)cc3)n21)c1ccc(F)c(F)c1
# 6                         Cc1ccc(Cl)cc1NC(=O)C1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21
# 7                                 Fc1ccc(CCOC2=CN=Cc3nnc(-c4ccc(Cl)cc4)n32)cc1F
# 8                            OC(COC1=CN=Cc2nnc(-c3ccc(C(F)(F)F)nc3)n21)c1ccccc1
# 9                              OC(COC1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21)c1ccccc1
# 10                                    Clc1ccc(-c2nnc3n2C(OCCc2ccccc2)=CN=C3)cc1
# 11                            OCC(COC1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21)c1ccccc1
# ...

# %%
sim_df_val = sim_df.ix[:,3:]
sim_df_val
# Out:
#                       3                     4                     5    \
# 0                    1.0,   0.7545999111015798,   0.8498031670414659,
# 1     0.7545999111015798,                  1.0,   0.7987824973160121,
# 2     0.8498031670414659,   0.7987824973160121,                  1.0,
# 3     0.8671497110335503,   0.8018865347231474,   0.9439289355514493,
# 4     0.8441694790388751,   0.7757617934507388,   0.9400168164743394,
# 5     0.5819731918327391,   0.6532496183133925,   0.6543872459278968,
# 6     0.8550581422292406,   0.8054736891270644,   0.9825990067547802,
# 7      0.596078709295507,   0.6750737726742204,    0.663131360854837,
# 8     0.6575876156742256,   0.6561072940588781,   0.6209981946318414,
# 9     0.6575337151872487,   0.7889687249321704,   0.7299814014787763,
# 10    0.5584446222504655,   0.7147228054239262,    0.653124328087771,
# 11    0.6445443779516935,   0.7885257603045213,   0.7147853472397042,
# ...

# %%
sim_df_val = sim_df_val.replace({',':''}, regex=True)
#sim_df_val

# %%
#convert to numeric
sim_df_val = pd.DataFrame(sim_df_val, dtype='float')
sim_df_val
# Out:
#           3         4         5         6         7         8         9    \
# 0    1.000000  0.754600  0.849803  0.867150  0.844169  0.581973  0.855058
# 1    0.754600  1.000000  0.798782  0.801887  0.775762  0.653250  0.805474
# 2    0.849803  0.798782  1.000000  0.943929  0.940017  0.654387  0.982599
# 3    0.867150  0.801887  0.943929  1.000000  0.941341  0.631721  0.951839
# 4    0.844169  0.775762  0.940017  0.941341  1.000000  0.654231  0.926312
# 5    0.581973  0.653250  0.654387  0.631721  0.654231  1.000000  0.662227
# 6    0.855058  0.805474  0.982599  0.951839  0.926312  0.662227  1.000000
# 7    0.596079  0.675074  0.663131  0.670541  0.686392  0.845473  0.680914
# 8    0.657588  0.656107  0.620998  0.619377  0.620739  0.740323  0.620998
# 9    0.657534  0.788969  0.729981  0.729383  0.718147  0.790192  0.729981
# 10   0.558445  0.714723  0.653124  0.669287  0.646835  0.793655  0.661811
# 11   0.644544  0.788526  0.714785  0.713819  0.703157  0.752430  0.714785
# ...

# %%
sim_df_val.columns = smiles_list
sim_df_val.index = smiles_list

# %%
sim_df_val
# Out:
# 2                                                                         O=C(Nc1ccnc(C(F)(F)F)c1)C1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21  \
# 2
# O=C(Nc1ccnc(C(F)(F)F)c1)C1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21                                                                  1.000000
# O=C(C1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21)N1Cc2ccccc2C1                                                                        0.754600
# Cc1c(Cl)cccc1NC(=O)C1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21                                                                       0.849803
# O=C(Nc1cccc(Cl)c1)C1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21                                                                        0.867150
# O=C(Nc1cccc(Cl)c1F)C1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21                                                                       0.844169
# COC(COC1=CN=Cc2nnc(-c3ccc(C#N)cc3)n21)c1ccc(F)c(F)c1                                                                        0.581973
# ...

# %%
#drop duplicates (it has to be both in rows and columns)
sim_df_val = sim_df_val.drop_duplicates()
sim_df_val =  sim_df_val.T.drop_duplicates().T

# %%
sim_df_val
# Out:
# 2                                                                         O=C(Nc1ccnc(C(F)(F)F)c1)C1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21  \
# 2
# O=C(Nc1ccnc(C(F)(F)F)c1)C1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21                                                                  1.000000
# O=C(C1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21)N1Cc2ccccc2C1                                                                        0.754600
# Cc1c(Cl)cccc1NC(=O)C1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21                                                                       0.849803
# O=C(Nc1cccc(Cl)c1)C1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21                                                                        0.867150
# O=C(Nc1cccc(Cl)c1F)C1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21                                                                       0.844169
# COC(COC1=CN=Cc2nnc(-c3ccc(C#N)cc3)n21)c1ccc(F)c(F)c1                                                                        0.581973
# ...

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(111)
cmap = cm.get_cmap('jet', 30)
cax = ax1.imshow(sim_df_val, interpolation="nearest", cmap=cmap)
ax1.grid(True)
plt.title('Similarity matrix')
#labels= smiles_list
#ax1.set_xticklabels(labels,fontsize=6)
#ax1.set_yticklabels(labels,fontsize=6)
plt.yticks(np.arange(0, 454, 50))
# Add colorbar, make sure to specify tick locations to match desired ticklabels
fig.colorbar(cax, ticks=[.75,.8,.85,.90,.95,1])
plt.show()

# %%
4+4
# Out:
# 8

# %%
#Loading data with compounds IDs, SMILES and information about their activity
osm_list = reading_csv()
osm_cleaned = data_preproc(osm_list)
osm_cleaned = osm_cleaned.reset_index(drop=True)
#Series 4
osm_series4 = series4_cmp(osm_cleaned)
osm_series4
# Out:
# Number of instances of each level of ION_ACTIVITY
#  0.0    395
# 1.0     55
# 0.5      5
# Name: ION_ACTIVITY, dtype: int64
# Number of instances of each level of ION_ACTIVITY
#  1.0    23
# 0.0    17
# 0.5     4
# Name: ION_ACTIVITY, dtype: int64
#            ID  \
# 0   OSM-S-175
# 1   OSM-S-177
# 2   OSM-S-201
# 3   OSM-S-202
# 4   OSM-S-204
# 5   OSM-S-218
# 6   OSM-S-218
# 7   OSM-S-254
# 8   OSM-S-272
# 9   OSM-S-278
# 10  OSM-S-279
# 11  OSM-S-293
# 12  OSM-S-353
# 13  OSM-S-363
# 14  OSM-S-364
# 15  OSM-S-366
# 16  OSM-S-367
# 17  OSM-S-368
# 18  OSM-S-369
# 19  OSM-S-370
# 20  OSM-S-371
# 21  OSM-S-372
# 22  OSM-S-373
# 23  OSM-S-374
# 24  OSM-S-375
# 25  OSM-S-376
# 26  OSM-S-378
# 27  OSM-S-379
# 28  OSM-S-380
# 29  OSM-S-382
# 30  OSM-S-383
# 31  OSM-S-384
# 32  OSM-S-385
# 33  OSM-S-386
# 34  OSM-S-387
# 35  OSM-S-388
# 36  OSM-S-389
# 37  OSM-S-390
# 38  MMV669304
# 39  MMV672990
# 40  MMV671927
# 41  MMV671677
# 42  MMV669360
# 43  MMV670762
#
# ...

# %%
osm_list
# Out:
#                  ID  \
# 0         OSM-S-175
# 1         OSM-S-176
# 2         OSM-S-177
# 3         OSM-S-178
# 4         OSM-S-179
# 5         OSM-S-180
# 6         OSM-S-181
# 7         OSM-S-182
# 8         OSM-S-183
# 9         OSM-S-184
# 10        OSM-S-185
# 11        OSM-S-186
# 12        OSM-S-187
# 13        OSM-S-188
# 14        OSM-S-189
# 15        OSM-S-190
# 16        OSM-S-191
# 17        OSM-S-201
# 18        OSM-S-202
# 19        OSM-S-204
# 20        OSM-S-206
# 21        OSM-S-207
# 22        OSM-S-208
# 23        OSM-S-218
# 24        OSM-S-219
# 25        OSM-S-220
# 26        OSM-S-254
# 27        OSM-S-255
# 28        OSM-S-256
# 29        OSM-S-257
# ..              ...
# 850        HTS04903
# 851        HTS08683
# 852        HTS12704
# 853        HTS13895
# 854        JFD02381
# 855         KM08910
# 856         KM09116
# 857         KM11054
# 858        NRB00250
# 859          S08837
# 860        SEW05657
# 861        SPB02821
# 862  KAE609 NITD609
# ...

# %%
smiles_series = pd.Series(smiles_list)

# %%
# Out:
# 0                    O=C(Nc1ccnc(C(F)(F)F)c1)C1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21
# 1                          O=C(C1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21)N1Cc2ccccc2C1
# 2                         Cc1c(Cl)cccc1NC(=O)C1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21
# 3                          O=C(Nc1cccc(Cl)c1)C1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21
# 4                         O=C(Nc1cccc(Cl)c1F)C1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21
# 5                          COC(COC1=CN=Cc2nnc(-c3ccc(C#N)cc3)n21)c1ccc(F)c(F)c1
# 6                         Cc1ccc(Cl)cc1NC(=O)C1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21
# 7                                 Fc1ccc(CCOC2=CN=Cc3nnc(-c4ccc(Cl)cc4)n32)cc1F
# 8                            OC(COC1=CN=Cc2nnc(-c3ccc(C(F)(F)F)nc3)n21)c1ccccc1
# 9                              OC(COC1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21)c1ccccc1
# 10                                    Clc1ccc(-c2nnc3n2C(OCCc2ccccc2)=CN=C3)cc1
# 11                            OCC(COC1=CN=Cc2nnc(-c3ccc(OC(F)F)cc3)n21)c1ccccc1
# ...
